# %% [markdown]
# ## 创建图表的通用方法
# * 导入库和方法
# * 准备数据
# * 设置输出模式
# * 创建图表
# * 显示图表

# %% [markdown]
# ### 创建柱状图并在浏览器显示

# %%
# 导入库函数
from bokeh.charts import Bar, output_file, show
# 准备数据
data = {"y":[1,2,3,4,5]}
# 输出到Line.HTML
output_file("lines.html", title="line plot example")
# 创建图表
p = Bar(data, title="Line Chart Example", xlabel="x", ylabel="values", width=400, height=400)
# 显示图表
show(p)
# Out:
# C:\Users\Bokkin Wang\Anaconda3\lib\site-packages\bokeh\core\json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):

# %% [markdown]
# ### 创建柱状图并在notebook显示

# %%
# 导入库函数
from bokeh.charts import Bar, output_notebook, show
# 准备数据
data = {"y":[1,2,3,4,5]}
# 输出到notebook
output_notebook()
# 创建图表
p = Bar(data, title="Line Chart Example", xlabel="x", ylabel="values", width=400, height=400)
# 显示图表
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f89eb68c-ad33-4d83-81a7-f7b5ab5a6e0b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f6f6bb41-d015-4b4e-a089-0fc3d986a074"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f6f6bb41-d015-4b4e-a089-0fc3d986a074");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6f6bb41-d015-4b4e-a089-0fc3d986a074");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6f6bb41-d015-4b4e-a089-0fc3d986a074' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1c585d1e-d61d-4147-98cd-9feadb23cf55":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"a6a266f9-ea03-426c-ad90-107c2b47094d","subtype":"Chart","type":"Plot"},"ticker":{"id":"78d8937f-9706-444c-9054-effb720cd34a","type":"BasicTicker"}},"id":"cdf6ef0a-d665-4890-b3ae-794addbb4340","type":"Grid"},{"attributes":{},"id":"0e1aa9df-bf73-4eab-b95b-02a5636ef955","type":"CategoricalTickFormatter"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"a807fa27-7722-4e68-b2c4-fdf842de1a4e","type":"GlyphRenderer"}]},"id":"fe027bfe-f0a0-4999-bf54-e0aa234fd902","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":4}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"index":[4],"label":[{"index":4}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4"],"y":[2.5]}},"id":"922eb365-752f-49ae-a760-9d4b200bb3e4","type":"ColumnDataSource"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"b30ad8a8-c864-4b07-bd45-bce860993036","type":"GlyphRenderer"}]},"id":"c6a63356-70ae-4870-a802-16e4dea092d1","type":"LegendItem"},{"attributes":{"data_source":{"id":"922eb365-752f-49ae-a760-9d4b200bb3e4","type":"ColumnDataSource"},"glyph":{"id":"440615fa-139d-4137-9f0f-91eabe21315f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8b6c14ce-2e60-4cc3-bc85-d6a6480f3a3a","type":"GlyphRenderer"},{"attributes":{"callback":null,"end